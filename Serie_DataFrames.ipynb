# %% [markdown]
# # Criando series
# # Criando Dataframes

# %%
import pandas as pd

# %%
estados= ['BA','PE','SP','MG','SC','RS']
indices= ['nordeste','nordeste', 'sudeste', 'sudeste', 'sul','sul']
minha_serie = pd.Series (estados,index=indices)
minha_serie
# Out:
# nordeste    BA
# nordeste    PE
# sudeste     SP
# sudeste     MG
# sul         SC
# sul         RS
# dtype: object

# %%
Uf= ['AC','AL','AM','BA',]
indice=['acre',"alagoas", 'Amapa', "Bahia"]
Uf = pd.Series(Uf)
Uf
# Out:
# 0    AC
# 1    AL
# 2    AM
# 3    BA
# dtype: object

# %%
Estados = ['bahia', 'Minas gerais', 'Pernambuco', 'Serigpe', 'Santa Catarina']
Estados = pd.Series(estados, name='Estados')
Estados
# Out:
# 0    BA
# 1    PE
# 2    SP
# 3    MG
# 4    SC
# 5    RS
# Name: Estados, dtype: object

# %%
Data= {

    "Regiões do Brasil" :["Sul",'Suldeste',' Centro-Oeste', 'Nordeste', ' Norte'],
    'População (Milhões)' : [28,79,14,46,13]
}
regioes_df= pd.DataFrame(Data)
regioes_df
# Out:
#   Regiões do Brasil  População (Milhões)
# 0               Sul                   28
# 1          Suldeste                   79
# 2      Centro-Oeste                   14
# 3          Nordeste                   46
# 4             Norte                   13

# %%
estados_df = pd.concat([Estados, Uf], axis='columns') # juntar o eixo da coluna. pd.contact junta todas variaveis usadas anteriormente
estados_df
# Out:
#   Estados    0
# 0      BA   AC
# 1      PE   AL
# 2      SP   AM
# 3      MG   BA
# 4      SC  NaN
# 5      RS  NaN

# %% [markdown]
# ## Lendo Aquivos

# %%
incendios_df = pd.read_csv('./amazon.csv', sep=',',encoding='cp1252')
incendios_df.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 6454 entries, 0 to 6453
Data columns (total 5 columns):

---  ------  --------------  -----
 0   year    6454 non-null   int64
 1   state   6454 non-null   object
 2   month   6454 non-null   object
 3   number  6454 non-null   float64
 4   date    6454 non-null   object
dtypes: float64(1), int64(1), object(3)
memory usage: 252.2+ KB
